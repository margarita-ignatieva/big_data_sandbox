# %% [markdown]
# ## Spark practice
#
# Before practice please go through following docks on spark and spark tutorials
#
# [spark docs](https://spark.apache.org/docs/latest/)
#
# [spark examples](https://sparkbyexamples.com/)
#
# <div class="alert alert-info">
#   <strong>task:</strong> before executing spark command run the code below to initiate spark session
# </div>

# %%
###### https://runawayhorse001.github.io/LearningApacheSpark/rdd.html add FROM HERE GOOOOOOOOOD TUTORIAL

# %%
# !pip3 install findspark

import findspark

findspark.init()

import os
import pyspark
from pyspark.sql import SQLContext, SparkSession

sc = SparkSession \
        .builder \
        .master('local[*]') \
        .appName("sparkFromJupyter") \
        .enableHiveSupport() \
        .getOrCreate()

sqlContext = SQLContext(sparkContext=sc.sparkContext, sparkSession=sc)
print("Spark Version: " + sc.version)
print("PySpark Version: " + pyspark.__version__)

# %% [markdown]
# ##  RDD, Dataset and Dataframe
#
# <hr style="border:3px solid #ADD8E6"> </hr>

# %% [markdown]
#  <ul>
#   <li>Create array of students with following data (having at least 5 rows):
#
# student_name
# avg_grade
# year (year of education)
#     </li>
#   <li>With the help of parallelize function - convert array to RDD</li>
#     <li>Use python standard help(...) command on created rdd, to see operations available</li>
# </ul>
#
#
# <div class="alert alert-success">
#   <strong>hint:</strong>use array of tupels
# </div>
#
# **What are the differences between RDD, Dataset, Dataframe?**
# **Why RDD is rarely used today?**
# **Does RDD support schema for stored data?**

# %%
arr = [("bob", 2), ("dd", 1), ("ddf", 6)]
rdd = sc.sparkContext.parallelize(arr)
help(rdd)
# Out:
# Help on RDD in module pyspark.rdd object:
#
# class RDD(builtins.object)
#  |  A Resilient Distributed Dataset (RDD), the basic abstraction in Spark.
#  |  Represents an immutable, partitioned collection of elements that can be
#  |  operated on in parallel.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, other)
#  |      Return the union of this RDD and another one.
#  |
#  |      Examples
#  |      --------
#  |      >>> rdd = sc.parallelize([1, 1, 2, 3])
#  |      >>> (rdd + rdd).collect()
#  |      [1, 1, 2, 3, 1, 1, 2, 3]
#  |
#  |  __getnewargs__(self)
#  |
#  |  __init__(self, jrdd, ctx, jrdd_deserializer=AutoBatchedSerializer(PickleSerializer()))
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  aggregate(self, zeroValue, seqOp, combOp)
#  |      Aggregate the elements of each partition, and then the results for all
# ...

# %% [markdown]
# Convert RDD to Dataframe with schema specified
#
# <div class="alert alert-info">
#   <strong>task:</strong> use StructType() to specify schema
# </div>
#
# Use help command to discover available operations
#
# **What are the benifits of using StructType() over passing just filed name in toDF() function?**

# %%
df = rdd.toDF()
df.show()
# Out:
# +---+---+
# | _1| _2|
# +---+---+
# |bob|  2|
# | dd|  1|
# |ddf|  6|
# +---+---+

# %% [markdown]
# Convert RDD to Dataset
#
# **What is Catalyst optimizer?**

# %%
ds = rdd.toDS()
sc.createDataset()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-ce3a723d7d4f> in <module>
#       1 # ds = rdd.toDS()
# ----> 2 sc.createDataset()
#
# AttributeError: 'SparkSession' object has no attribute 'createDataset'

# %% [markdown]
# Add 5 partitions to RDD
#
#
# **What's the difference between repartition() andd coalesce() functions?**

# %% [markdown]
# Create broadcast variable
#
#
# **What's the difference between accumulator and broadcast variables?**

# %% [markdown]
# Add column

# %%
# Out:
# Spark Version: 3.2.1
# PySpark Version: 3.2.1
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |  default|     empl|      false|
# |  default|     empy|      false|
# |  default|      tab|      false|
# +---------+---------+-----------+
#
# ++
# ||
# ++
# ++
